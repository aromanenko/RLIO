# %%
import numpy as np
import optuna
import pandas as pd
import xgboost as xgb
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import Ridge
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler

import restore_demand_beta as dem

# %% [markdown]
# # Чтение таблиц

# %%
df = pd.read_csv("MERGE_TABLE_STORE_4600.csv", sep=";")

# %%
# Товары

# %%
id_list = df.product_id.value_counts().nlargest(40).index.tolist()

# %%
print(id_list)
# Out:
# [555800, 616400, 564900, 582700, 404500, 589400, 582800, 1518900, 835000, 587400, 617400, 819800, 1843100, 631500, 7562300, 11637400, 3539700, 3540400, 12906800, 4095600, 886100, 4212800, 706600, 9339400, 589700, 625700, 560100, 559800, 490400, 1617800, 744200, 720500, 4285500, 615200, 1453400, 4043300, 571300, 808700, 101300, 6783400]

# %% [markdown]
# # Перевод даты

# %%
def get_date_df(df, id_list):
    df_model = df[df.product_id.isin(id_list)]
    df_model.loc[:, "curr_date"] = pd.to_datetime(df_model.curr_date)
    df_model = df_model.set_index("curr_date")
    return df_model

# %% [markdown]
# # Создаём датасет для трейна

# %%
def df_preprocessing(df_train):
    # add data as a feature
    df_train["data"] = df_train.index

    # add dates
    df_train["day"] = pd.to_datetime(df_train["data"]).dt.day
    df_train["weekday"] = pd.to_datetime(df_train["data"]).dt.weekday
    df_train["month"] = pd.to_datetime(df_train["data"]).dt.month
    df_train["year"] = pd.to_datetime(df_train["data"]).dt.year

    # add Deficit days
    df_train["deficit"] = np.where(
        (df_train["stock"] <= 0)
        | (df_train["stock"] <= df_train["s_qty"])
        | (df_train["stock"].isna())
        | (df_train["s_qty"].isna()),
        1,
        0,
    )

    return df_train

# %%
def df_preprocess_windows(df_train):
    # Без сдвига
    df_train["s_qty win15"] = (
        df_train["s_qty"]
        .rolling(15, min_periods=1, center=True)
        .apply(np.nanmean)
    )
    df_train["s_qty win15"].fillna(method="ffill", inplace=True)
    df_train["s_qty win15"].fillna(0, inplace=True)

    # Сдвиг на 7 дней назад
    df_train["s_qty win15 m7"] = (
        df_train["s_qty"]
        .rolling(15, min_periods=1, center=True)
        .apply(np.nanmean)
        .shift(-7)
    )
    df_train["s_qty win15 m7"].fillna(method="ffill", inplace=True)
    df_train["s_qty win15 m7"].fillna(0, inplace=True)

    # Сдвиг на 7 дней вперёд
    df_train["s_qty win15 p7"] = (
        df_train["s_qty"]
        .rolling(15, min_periods=1, center=True)
        .apply(np.nanmean)
        .shift(7)
    )
    df_train["s_qty win15 p7"].fillna(method="ffill", inplace=True)
    df_train["s_qty win15 p7"].fillna(0, inplace=True)

    # Без сдвига
    df_train["s_qty win7"] = (
        df_train["s_qty"]
        .rolling(7, min_periods=1, center=True)
        .apply(np.nanmean)
    )
    df_train["s_qty win7"].fillna(method="ffill", inplace=True)
    df_train["s_qty win7"].fillna(0, inplace=True)

    # Сдвиг на 7 дней назад
    df_train["s_qty win7 m7"] = (
        df_train["s_qty"]
        .rolling(7, min_periods=1, center=True)
        .apply(np.nanmean)
        .shift(-7)
    )
    df_train["s_qty win7 m7"].fillna(method="ffill", inplace=True)
    df_train["s_qty win7 m7"].fillna(0, inplace=True)

    # Сдвиг на 7 дней вперёд
    df_train["s_qty win7 p7"] = (
        df_train["s_qty"]
        .rolling(7, min_periods=1, center=True)
        .apply(np.nanmean)
        .shift(7)
    )
    df_train["s_qty win7 p7"].fillna(method="ffill", inplace=True)
    df_train["s_qty win7 p7"].fillna(0, inplace=True)

    return df_train

# %% [markdown]
# # Выберем магазины для обучения

# %%
shops_list = [16500]

# %%
for shop in shops_list:
    df = pd.read_csv("MERGE_TABLE_STORE_{}.csv".format(shop), sep=";")
    df_model = get_date_df(df, id_list)
    df_model = df_preprocessing(df_model)
    df_model = df_preprocess_windows(df_model)
    df_train = df_train.append(df_model)
# Out:
# /home/alexander/PythonProjects/MO/venb/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
df_train
# Out:
#             product_id  store_id  s_qty  flg_spromo  stock       data  day  \
# curr_date
# 2016-04-15      147600     16500    0.0           0    0.0 2016-04-15   15
# 2016-04-16      147600     16500    NaN           0    3.0 2016-04-16   16
# 2016-04-17      147600     16500    NaN           0    3.0 2016-04-17   17
# 2016-04-18      147600     16500    NaN           0    3.0 2016-04-18   18
# 2016-04-19      147600     16500    1.0           0    3.0 2016-04-19   19
# ...                ...       ...    ...         ...    ...        ...  ...
# 2019-10-30    12906800     32700    NaN           0    2.0 2019-10-30   30
# 2019-10-31    12906800     32700    NaN           0    2.0 2019-10-31   31
# 2019-11-01    12906800     32700    NaN           0    2.0 2019-11-01    1
# 2019-11-02    12906800     32700    NaN           0    2.0 2019-11-02    2
# 2019-11-03    12906800     32700    NaN           0    2.0 2019-11-03    3
#
#             weekday  month  year  deficit  s_qty win15  s_qty win15 m7  \
# curr_date
# 2016-04-15        4      4  2016        1     0.500000        0.500000
# 2016-04-16        5      4  2016        1     0.666667        0.666667
# 2016-04-17        6      4  2016        1     0.666667        0.666667
# 2016-04-18        0      4  2016        1     0.666667        0.666667
# 2016-04-19        1      4  2016        0     0.666667        0.666667
# ...             ...    ...   ...      ...          ...             ...
# 2019-10-30        2     10  2019        1     0.000000        0.000000
# 2019-10-31        3     10  2019        1     0.000000        0.000000
# 2019-11-01        4     11  2019        1     0.000000        0.000000
# 2019-11-02        5     11  2019        1     0.000000        0.000000
# 2019-11-03        6     11  2019        1     0.000000        0.000000
#
#             s_qty win15 p7  s_qty win7  s_qty win7 m7  s_qty win7 p7  \
# curr_date
# 2016-04-15             0.0         0.0            1.0            0.0
# 2016-04-16             0.0         0.5            1.0            0.0
# 2016-04-17             0.0         0.5            1.0            0.0
# 2016-04-18             0.0         0.5            1.0            0.0
# 2016-04-19             0.0         1.0            0.5            0.0
# ...                    ...         ...            ...            ...
# 2019-10-30             0.0         0.0            0.0            0.0
# 2019-10-31             0.0         0.0            0.0            0.0
# 2019-11-01             0.0         0.0            0.0            0.0
# 2019-11-02             0.0         0.0            0.0            0.0
# 2019-11-03             0.0         0.0            0.0            0.0
#
#             real demand
# curr_date
# 2016-04-15          NaN
# 2016-04-16          NaN
# 2016-04-17          NaN
# 2016-04-18          NaN
# 2016-04-19          1.0
# ...                 ...
# 2019-10-30          NaN
# 2019-10-31          NaN
# 2019-11-01          NaN
# 2019-11-02          NaN
# 2019-11-03          NaN
#
# [164879 rows x 18 columns]

# %% [markdown]
# # Отделим часть, которая подходит под обучение

# %%
df_train["real demand"] = np.where(df_train["s_qty"] < df_train["stock"], df_train["s_qty"], np.nan)

# %%
df_train_demand = df_train[df_train["real demand"].notna()]
df_train_demand
# Out:
#             product_id  store_id  s_qty  flg_spromo  stock       data  day  \
# curr_date
# 2016-04-19      147600     16500    1.0           0    3.0 2016-04-19   19
# 2016-04-23      147600     16500    1.0           0    2.0 2016-04-23   23
# 2016-04-29      147600     16500    0.0           0    1.0 2016-04-29   29
# 2016-05-13      147600     16500    1.0           0    4.0 2016-05-13   13
# 2016-05-26      147600     16500    1.0           0    3.0 2016-05-26   26
# ...                ...       ...    ...         ...    ...        ...  ...
# 2019-04-24    12906800     32700    1.0           0    5.0 2019-04-24   24
# 2019-05-19    12906800     32700    1.0           0    4.0 2019-05-19   19
# 2019-07-13    12906800     32700    1.0           0    3.0 2019-07-13   13
# 2019-07-25    12906800     32700    1.0           0    2.0 2019-07-25   25
# 2019-07-27    12906800     32700    0.0           0    1.0 2019-07-27   27
#
#             weekday  month  year  deficit  s_qty win15  s_qty win15 m7  \
# curr_date
# 2016-04-19        1      4  2016        0     0.666667        0.666667
# 2016-04-23        5      4  2016        0     0.666667        0.500000
# 2016-04-29        4      4  2016        0     0.500000        0.500000
# 2016-05-13        4      5  2016        0     1.000000        1.000000
# 2016-05-26        3      5  2016        0     0.666667        0.666667
# ...             ...    ...   ...      ...          ...             ...
# 2019-04-24        2      4  2019        0     1.000000        1.000000
# 2019-05-19        6      5  2019        0     1.000000        1.000000
# 2019-07-13        5      7  2019        0     1.000000        0.666667
# 2019-07-25        3      7  2019        0     0.500000        0.500000
# 2019-07-27        5      7  2019        0     0.500000        0.000000
#
#             s_qty win15 p7  s_qty win7  s_qty win7 m7  s_qty win7 p7  \
# curr_date
# 2016-04-19        0.000000         1.0            0.5            0.0
# 2016-04-23        0.666667         1.0            0.0            0.5
# 2016-04-29        0.500000         0.0            0.0            1.0
# 2016-05-13        0.500000         1.0            1.0            0.0
# 2016-05-26        1.000000         1.0            0.5            1.0
# ...                    ...         ...            ...            ...
# 2019-04-24        1.500000         1.0            1.0            2.0
# 2019-05-19        1.000000         1.0            1.0            1.0
# 2019-07-13        1.000000         1.0            1.0            1.0
# 2019-07-25        1.000000         0.5            0.0            1.0
# 2019-07-27        0.666667         0.5            0.0            1.0
#
#             real demand
# curr_date
# 2016-04-19          1.0
# 2016-04-23          1.0
# 2016-04-29          0.0
# 2016-05-13          1.0
# 2016-05-26          1.0
# ...                 ...
# 2019-04-24          1.0
# 2019-05-19          1.0
# 2019-07-13          1.0
# 2019-07-25          1.0
# 2019-07-27          0.0
#
# [27373 rows x 18 columns]

# %% [markdown]
# # Создание модели

# %%
# Создание метрики
def my_smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

smape = make_scorer(my_smape, greater_is_better=False)

# %%
y = df_train_demand["real demand"]
X = df_train_demand.drop(columns=["real demand", "s_qty", "stock", "data"])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=808)

# %%
X
# Out:
#             product_id  store_id  flg_spromo  day  weekday  month  year  \
# curr_date
# 2016-04-19      147600     16500           0   19        1      4  2016
# 2016-04-23      147600     16500           0   23        5      4  2016
# 2016-04-29      147600     16500           0   29        4      4  2016
# 2016-05-13      147600     16500           0   13        4      5  2016
# 2016-05-26      147600     16500           0   26        3      5  2016
# ...                ...       ...         ...  ...      ...    ...   ...
# 2019-04-24    12906800     32700           0   24        2      4  2019
# 2019-05-19    12906800     32700           0   19        6      5  2019
# 2019-07-13    12906800     32700           0   13        5      7  2019
# 2019-07-25    12906800     32700           0   25        3      7  2019
# 2019-07-27    12906800     32700           0   27        5      7  2019
#
#             deficit  s_qty win15  s_qty win15 m7  s_qty win15 p7  s_qty win7  \
# curr_date
# 2016-04-19        0     0.666667        0.666667        0.000000         1.0
# 2016-04-23        0     0.666667        0.500000        0.666667         1.0
# 2016-04-29        0     0.500000        0.500000        0.500000         0.0
# 2016-05-13        0     1.000000        1.000000        0.500000         1.0
# 2016-05-26        0     0.666667        0.666667        1.000000         1.0
# ...             ...          ...             ...             ...         ...
# 2019-04-24        0     1.000000        1.000000        1.500000         1.0
# 2019-05-19        0     1.000000        1.000000        1.000000         1.0
# 2019-07-13        0     1.000000        0.666667        1.000000         1.0
# 2019-07-25        0     0.500000        0.500000        1.000000         0.5
# 2019-07-27        0     0.500000        0.000000        0.666667         0.5
#
#             s_qty win7 m7  s_qty win7 p7
# curr_date
# 2016-04-19            0.5            0.0
# 2016-04-23            0.0            0.5
# 2016-04-29            0.0            1.0
# 2016-05-13            1.0            0.0
# 2016-05-26            0.5            1.0
# ...                   ...            ...
# 2019-04-24            1.0            2.0
# 2019-05-19            1.0            1.0
# 2019-07-13            1.0            1.0
# 2019-07-25            0.0            1.0
# 2019-07-27            0.0            1.0
#
# [27373 rows x 14 columns]

# %%
numeric = [
    "s_qty win15",
    "s_qty win15 m7",
    "s_qty win15 p7",
    "s_qty win7",
    "s_qty win7 m7",
    "s_qty win7 p7",
]

categorical = [
    "product_id",
    "store_id",
    "day",
    "weekday",
    "month",
    "year",
    "deficit",
    "flg_spromo",
]

# %%
column_transformer = ColumnTransformer(
    [
        ("ohe", OneHotEncoder(handle_unknown="ignore"), categorical),
        ("scaling", StandardScaler(), numeric),
    ]
)

# %%
def objective(trial):
    y = df_train_demand["real demand"]
    X = df_train_demand.drop(columns=["real demand", "s_qty", "stock", "data"])
    
    pipeline = Pipeline(
        steps=[
            ("ohe_and_scaling", column_transformer),
        ]
    )
    X = pipeline.fit_transform(X, y)
    train_x, test_x, train_y, test_y = train_test_split(
        X, y, test_size=0.2, random_state=808
    )

    param = {
        "lambda": trial.suggest_loguniform("lambda", 1e-3, 10.0),
        "alpha": trial.suggest_loguniform("alpha", 1e-3, 10.0),
        "colsample_bytree": trial.suggest_categorical(
            "colsample_bytree", [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
        ),
        "subsample": trial.suggest_categorical(
            "subsample", [0.4, 0.5, 0.6, 0.7, 0.8, 1.0]
        ),
        "learning_rate": trial.suggest_categorical(
            "learning_rate", [0.17, 0.2, 0.22, 0.26, 0.28, 0.31]
        ),
        "n_estimators": 4000,
        "max_depth": trial.suggest_categorical("max_depth", [3, 4, 5, 6]),
        "random_state": trial.suggest_categorical(
            "random_state", [24, 808, 2020]
        ),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 300),
    }
    model = xgb.XGBRegressor(**param)
    
    model.fit(
        train_x,
        train_y,
        eval_set=[(test_x, test_y)],
        early_stopping_rounds=100,
        verbose=False,
    )
    preds = model.predict(test_x)
    smape_error = my_smape(preds, test_y)

    return smape_error

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2021-06-05 03:04:25,127] A new study created in memory with name: no-name-f37a7112-0cf2-423a-ad16-15a865256540
# [I 2021-06-05 03:04:27,480] Trial 0 finished with value: 48.612584882059075 and parameters: {'lambda': 0.03048758982817561, 'alpha': 0.0010217996528778704, 'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.22, 'max_depth': 4, 'random_state': 2020, 'min_child_weight': 290}. Best is trial 0 with value: 48.612584882059075.
# [I 2021-06-05 03:04:28,613] Trial 1 finished with value: 48.35567101504945 and parameters: {'lambda': 5.073150512659224, 'alpha': 0.06422657753751622, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.17, 'max_depth': 3, 'random_state': 2020, 'min_child_weight': 8}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:34,193] Trial 2 finished with value: 49.1498476706082 and parameters: {'lambda': 0.010695016270567466, 'alpha': 0.001244637315977206, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.28, 'max_depth': 5, 'random_state': 2020, 'min_child_weight': 211}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:35,548] Trial 3 finished with value: 49.76725847643981 and parameters: {'lambda': 2.4474684333480115, 'alpha': 0.001321410446134078, 'colsample_bytree': 0.3, 'subsample': 0.7, 'learning_rate': 0.31, 'max_depth': 3, 'random_state': 2020, 'min_child_weight': 49}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:37,387] Trial 4 finished with value: 49.41588182993416 and parameters: {'lambda': 0.17373863997193778, 'alpha': 0.0011223531006651869, 'colsample_bytree': 0.4, 'subsample': 0.4, 'learning_rate': 0.2, 'max_depth': 6, 'random_state': 24, 'min_child_weight': 163}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:39,097] Trial 5 finished with value: 48.49003586304108 and parameters: {'lambda': 0.022314850954010024, 'alpha': 0.025156646338541446, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.2, 'max_depth': 5, 'random_state': 808, 'min_child_weight': 255}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:42,772] Trial 6 finished with value: 49.38615531074262 and parameters: {'lambda': 0.018682288867248684, 'alpha': 0.04938903328313696, 'colsample_bytree': 0.3, 'subsample': 0.7, 'learning_rate': 0.22, 'max_depth': 4, 'random_state': 2020, 'min_child_weight': 226}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:43,932] Trial 7 finished with value: 48.83134305832924 and parameters: {'lambda': 0.009750328760723171, 'alpha': 0.0021969393776504987, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.31, 'max_depth': 4, 'random_state': 24, 'min_child_weight': 11}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:45,644] Trial 8 finished with value: 49.06565910437928 and parameters: {'lambda': 9.380820889685323, 'alpha': 0.02214020331106265, 'colsample_bytree': 0.5, 'subsample': 0.8, 'learning_rate': 0.28, 'max_depth': 3, 'random_state': 24, 'min_child_weight': 274}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:48,049] Trial 9 finished with value: 49.24554361016835 and parameters: {'lambda': 0.0034978845799841407, 'alpha': 0.3523366254375659, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.22, 'max_depth': 4, 'random_state': 808, 'min_child_weight': 215}. Best is trial 1 with value: 48.35567101504945.
# [I 2021-06-05 03:04:49,380] Trial 10 finished with value: 48.29439150453876 and parameters: {'lambda': 0.39346258444231347, 'alpha': 7.867651757035861, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.17, 'max_depth': 3, 'random_state': 2020, 'min_child_weight': 71}. Best is trial 10 with value: 48.29439150453876.
# [I 2021-06-05 03:04:52,072] Trial 11 finished with value: 48.31076180665756 and parameters: {'lambda': 0.538462615651159, 'alpha': 8.491148587070388, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.17, 'max_depth': 3, 'random_state': 2020, 'min_child_weight': 80}. Best is trial 10 with value: 48.29439150453876.
# [I 2021-06-05 03:04:53,135] Trial 12 finished with value: 48.31036736676157 and parameters: {'lambda': 0.4797186999172253, 'alpha': 7.978767452604821, 'colsample_bytree': 0.8, 'subsample': 1.0, 'learning_rate': 0.17, 'max_depth': 3, 'random_state': 2020, 'min_child_weight':
 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.2, 'max_depth': 4, 'random_state': 24, 'min_child_weight': 15}. Best is trial 43 with value: 47.21906507974068.
# [I 2021-06-05 03:05:37,550] Trial 46 finished with value: 47.54470697815224 and parameters: {'lambda': 7.484939725984351, 'alpha': 0.08867147948050072, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.2, 'max_depth': 6, 'random_state': 24, 'min_child_weight': 13}. Best is trial 43 with value: 47.21906507974068.
# [I 2021-06-05 03:05:39,854] Trial 47 finished with value: 47.52116825011681 and parameters: {'lambda': 3.206082980959768, 'alpha': 0.0035127990475387057, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.2, 'max_depth': 6, 'random_state': 24, 'min_child_weight': 2}. Best is trial 43 with value: 47.21906507974068.
# [I 2021-06-05 03:05:40,835] Trial 48 finished with value: 48.21006568914607 and parameters: {'lambda': 9.859319002600467, 'alpha': 0.04304111012398103, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.31, 'max_depth': 6, 'random_state': 24, 'min_child_weight': 30}. Best is trial 43 with value: 47.21906507974068.
# [I 2021-06-05 03:05:42,044] Trial 49 finished with value: 49.62106333429482 and parameters: {'lambda': 1.663908861056338, 'alpha': 0.01331668321690509, 'colsample_bytree': 0.3, 'subsample': 0.5, 'learning_rate': 0.28, 'max_depth': 6, 'random_state': 24, 'min_child_weight': 53}. Best is trial 43 with value: 47.21906507974068.
# Number of finished trials: 50
# Best trial: {'lambda': 3.874667405571208, 'alpha': 0.02702827007724924, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.2, 'max_depth': 6, 'random_state': 24, 'min_child_weight': 19}

# %%
study.best_trial.params
# Out:
# {'lambda': 3.874667405571208,
#  'alpha': 0.02702827007724924,
#  'colsample_bytree': 0.9,
#  'subsample': 0.7,
#  'learning_rate': 0.2,
#  'max_depth': 6,
#  'random_state': 24,
#  'min_child_weight': 19}

# %%
xgb_cool = xgb.XGBRegressor(**study.best_trial.params)

# %%
pipeline = Pipeline(
        steps=[
            ("ohe_and_scaling", column_transformer),
            ("xgb", xgb_cool)
        ]
    )

# %%
model = pipeline
print((-cross_val_score(model, X, y, cv=5, scoring=smape)).sum() / 5)
# Out:
# 48.23109396774855

# %%
linreg = Ridge()

# %%
pipeline = Pipeline(
        steps=[
            ("ohe_and_scaling", column_transformer),
            ("linreg", linreg)
        ]
    )

# %%
model = pipeline
print((-cross_val_score(model, X, y, cv=5, scoring=smape)).sum() / 5)
# Out:
# 52.68972159548291

# %% [markdown]
# # Сравним результаты с window и promo

# %%
shop_number = 4600

# %%
df_model = pd.read_csv("MERGE_TABLE_STORE_{}.csv".format(shop_number), sep=";")
df_model = df_model[df_model.product_id.isin(id_list)]

# %%
df_model.loc[:, "curr_date"] = pd.to_datetime(df_model.curr_date)

# %%
df_model["lambda"] = np.nan

# %%
df_new = pd.DataFrame(columns = list(df_model.columns))

# %%
for product in np.unique(X.product_id):
    df = df_model.loc[(df_model["product_id"] == product) & (df_model["store_id"] == shop_number)]
    df = dem.restore_demand(df, product, store_id=shop_number, method="promo")
    df_new = df_new.append(df)

# %%
df_model = df_new

# %%
df_model["real demand"] = np.where(df_model["s_qty"] < df_model["stock"], df_model["s_qty"], np.nan)
df_model_demand = df_model[df_model["real demand"].notna()]

# %%
df_model_demand
# Out:
#            product_id store_id curr_date  s_qty flg_spromo  stock    lambda  \
# 2016-05-02     147600     4600       NaN    1.0          0    3.0  0.928571
# 2016-06-05     147600     4600       NaN    1.0          0    2.0  0.928571
# 2016-06-07     147600     4600       NaN    0.0          0    1.0  0.928571
# 2016-07-27     147600     4600       NaN    1.0          0    4.0  0.928571
# 2016-09-26     147600     4600       NaN    2.0          0    3.0  0.928571
# ...               ...      ...       ...    ...        ...    ...       ...
# 2019-10-09   15886000     4600       NaN    1.0          0   16.0  1.530000
# 2019-10-10   15886000     4600       NaN    1.0          0   15.0  1.530000
# 2019-10-13   15886000     4600       NaN    1.0          0   14.0  1.530000
# 2019-10-14   15886000     4600       NaN    1.0          0   13.0  1.530000
# 2019-10-22   15886000     4600       NaN    1.0          0   12.0  1.530000
#
#             demand  real demand
# 2016-05-02     1.0          1.0
# 2016-06-05     1.0          1.0
# 2016-06-07     2.0          0.0
# 2016-07-27     2.0          1.0
# 2016-09-26     2.0          2.0
# ...            ...          ...
# 2019-10-09     2.0          1.0
# 2019-10-10     1.0          1.0
# 2019-10-13     1.0          1.0
# 2019-10-14     1.0          1.0
# 2019-10-22     1.0          1.0
#
# [10363 rows x 9 columns]

# %%
my_smape(df_model_demand["lambda"], df_model_demand["real demand"])
# Out:
# 52.9211990867907

# %% [markdown]
# Среднее по промо и непромо дням:

# %%
shop_number = 4600

# %%
df_model = pd.read_csv("MERGE_TABLE_STORE_{}.csv".format(shop_number), sep=";")
df_model = df_model[df_model.product_id.isin(id_list)]

# %%
df_model.loc[:, "curr_date"] = pd.to_datetime(df_model.curr_date)

# %%
df_model["lambda"] = np.nan
df_new = pd.DataFrame(columns = list(df_model.columns))

# %%
for product in np.unique(X.product_id):
    df = df_model.loc[(df_model["product_id"] == product) & (df_model["store_id"] == shop_number)]
    df = dem.restore_demand(df, product, store_id=shop_number, method="window")
    df_new = df_new.append(df)

# %%
df_model = df_new
df_model["real demand"] = np.where(df_model["s_qty"] < df_model["stock"], df_model["s_qty"], np.nan)
df_model_demand = df_model[df_model["real demand"].notna()]

# %%
df_model_demand
# Out:
#            product_id store_id curr_date  s_qty flg_spromo  stock  lambda  \
# 2016-05-02     147600     4600       NaN    1.0          0    3.0     0.0
# 2016-06-05     147600     4600       NaN    1.0          0    2.0     0.0
# 2016-06-07     147600     4600       NaN    0.0          0    1.0     0.0
# 2016-07-27     147600     4600       NaN    1.0          0    4.0     0.0
# 2016-09-26     147600     4600       NaN    2.0          0    3.0     0.0
# ...               ...      ...       ...    ...        ...    ...     ...
# 2019-10-09   15886000     4600       NaN    1.0          0   16.0     1.0
# 2019-10-10   15886000     4600       NaN    1.0          0   15.0     1.0
# 2019-10-13   15886000     4600       NaN    1.0          0   14.0     1.0
# 2019-10-14   15886000     4600       NaN    1.0          0   13.0     1.0
# 2019-10-22   15886000     4600       NaN    1.0          0   12.0     1.0
#
#             real demand
# 2016-05-02          1.0
# 2016-06-05          1.0
# 2016-06-07          0.0
# 2016-07-27          1.0
# 2016-09-26          2.0
# ...                 ...
# 2019-10-09          1.0
# 2019-10-10          1.0
# 2019-10-13          1.0
# 2019-10-14          1.0
# 2019-10-22          1.0
#
# [10363 rows x 8 columns]

# %%
my_smape(df_model_demand["lambda"], df_model_demand["real demand"])
# Out:
# 53.28514953848695
